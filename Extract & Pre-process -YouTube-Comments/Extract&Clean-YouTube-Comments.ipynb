# %% [markdown]
# # Part 1
# ## Comments Extraction

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir('/content/drive/My Drive/Analytic-Steps-blogs/YouTube/Sentiment/ThirdBlog/')

# %% [markdown]
# ## Install the relevant libraries

# %%
# !pip install google-api-python-client
# !pip install google-auth google-auth-oauthlib google-auth-httplib2
# !pip install demoji
# !pip install pandas
# !pip install langdetect
# Out:
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.6/dist-packages (1.7.12)
# Requirement already satisfied: six<2dev,>=1.6.1 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client) (1.12.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client) (0.0.3)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client) (3.0.1)
# Requirement already satisfied: google-auth>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client) (1.7.2)
# Requirement already satisfied: httplib2<1dev,>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client) (0.17.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.4.1->google-api-python-client) (0.2.8)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.4.1->google-api-python-client) (47.1.1)
# Requirement already satisfied: cachetools<3.2,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.4.1->google-api-python-client) (3.1.1)
# Requirement already satisfied: rsa<4.1,>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.4.1->google-api-python-client) (4.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.6/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->google-api-python-client) (0.4.8)
# Requirement already satisfied: google-auth in /usr/local/lib/python3.6/dist-packages (1.7.2)
# Requirement already satisfied: google-auth-oauthlib in /usr/local/lib/python3.6/dist-packages (0.4.1)
# Requirement already satisfied: google-auth-httplib2 in /usr/local/lib/python3.6/dist-packages (0.0.3)
# Requirement already satisfied: rsa<4.1,>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from google-auth) (4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth) (0.2.8)
# Requirement already satisfied: cachetools<3.2,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth) (3.1.1)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from google-auth) (1.12.0)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.6/dist-packages (from google-auth) (47.1.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib) (1.3.0)
# Requirement already satisfied: httplib2>=0.9.1 in /usr/local/lib/python3.6/dist-packages (from google-auth-httplib2) (0.17.4)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from rsa<4.1,>=3.1.4->google-auth) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.1.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (2.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (2020.4.5.1)
# Collecting demoji
#   Downloading https://files.pythonhosted.org/packages/da/0b/d008f26ebbfd86d21117267e627f2f7359c76e5ecbeba08d8f631f4092c4/demoji-0.2.1-py2.py3-none-any.whl
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from demoji) (47.1.1)
# Requirement already satisfied: requests<3.0.0 in /usr/local/lib/python3.6/dist-packages (from demoji) (2.23.0)
# Collecting colorama
#   Downloading https://files.pythonhosted.org/packages/c9/dc/45cdef1b4d119eb96316b3117e6d5708a08029992b2fee2c143c7a0a5cc5/colorama-0.4.3-py2.py3-none-any.whl
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0->demoji) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0->demoji) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0->demoji) (2020.4.5.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0->demoji) (2.9)
# Installing collected packages: colorama, demoji
# Successfully installed colorama-0.4.3 demoji-0.2.1
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (1.0.4)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas) (2018.9)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from pandas) (1.18.4)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.6.1->pandas) (1.12.0)
# Collecting langdetect
#   Downloading https://files.pythonhosted.org/packages/56/a3/8407c1e62d5980188b4acc45ef3d94b933d14a2ebc9ef3505f22cf772570/langdetect-1.0.8.tar.gz (981kB)
#      |████████████████████████████████| 983kB 2.8MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from langdetect) (1.12.0)
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.8-cp36-none-any.whl size=993193 sha256=abc82b47b8323bed2807f05e793317b429682daaf39235d5d986a961b663bcaf
#   Stored in directory: /root/.cache/pip/wheels/8d/b3/aa/6d99de9f3841d7d3d40a60ea06e6d669e8e5012e6c8b947a57
# Successfully built langdetect
# Installing collected packages: langdetect
# Successfully installed langdetect-1.0.8

# %%
pip install google-auth google-auth-oauthlib google-auth-httplib2
# Out:
# Requirement already satisfied: google-auth in /usr/local/lib/python3.6/dist-packages (1.7.2)
# Requirement already satisfied: google-auth-oauthlib in /usr/local/lib/python3.6/dist-packages (0.4.1)
# Requirement already satisfied: google-auth-httplib2 in /usr/local/lib/python3.6/dist-packages (0.0.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth) (0.2.8)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.6/dist-packages (from google-auth) (47.1.1)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from google-auth) (1.12.0)
# Requirement already satisfied: cachetools<3.2,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth) (3.1.1)
# Requirement already satisfied: rsa<4.1,>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from google-auth) (4.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib) (1.3.0)
# Requirement already satisfied: httplib2>=0.9.1 in /usr/local/lib/python3.6/dist-packages (from google-auth-httplib2) (0.17.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.6/dist-packages (from pyasn1-modules>=0.2.1->google-auth) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.1.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (2.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (2020.4.5.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.0.4)

# %%
 pip install langdetect
# Out:
# Collecting langdetect
#   Downloading https://files.pythonhosted.org/packages/56/a3/8407c1e62d5980188b4acc45ef3d94b933d14a2ebc9ef3505f22cf772570/langdetect-1.0.8.tar.gz (981kB)
#      |████████████████████████████████| 983kB 3.4MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from langdetect) (1.12.0)
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.8-cp36-none-any.whl size=993193 sha256=6f6da426446c97ebc805f3469a0f5fcc8779ae5313ce5814d02bf737fe15732a
#   Stored in directory: /root/.cache/pip/wheels/8d/b3/aa/6d99de9f3841d7d3d40a60ea06e6d669e8e5012e6c8b947a57
# Successfully built langdetect
# Installing collected packages: langdetect
# Successfully installed langdetect-1.0.8

# %%
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow
import pandas as pd
import demoji
from langdetect import detect
import re   # regular expression

# %%
import pandas as pd

# %% [markdown]
# ### provide path to the `client_secret.json` file which will be useful inthe authorization

# %%
CLIENT_SECRETS_FILE = "client_secret.json"

# %%
SCOPES = ['https://www.googleapis.com/auth/youtube.force-ssl']
API_SERVICE_NAME = 'youtube'
API_VERSION = 'v3'

# %%
def get_authenticated_service():
  flow = InstalledAppFlow.from_client_secrets_file(CLIENT_SECRETS_FILE, SCOPES)
  credentials = flow.run_console()
  return build(API_SERVICE_NAME, API_VERSION, credentials = credentials)

# %%
os.environ['OAUTHLIB_INSECURE_TRANSPORT'] = '1'
service = get_authenticated_service()
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=196238360462-rfa74p603hoht5o0k5s03bdee30srvvt.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fyoutube.force-ssl&state=3MKcNr9jb1ZHBXJfau8DOKKPKI4H6E&prompt=consent&access_type=offline
# Enter the authorization code: 4/0gH3LKszOstD6omCljc8I71MA0oD1kbY_iK9oImKxkms_291fZbWqiQ

# %% [markdown]
# ### Set the search query i.e. video of which comments will be extracted

# %%
# query = "Sia - Cheap Thrills (Lyric Video) ft. Sean Paul"
# query = "Clean Bandit - Rockabye (feat. Sean Paul & Anne-Marie) [Official Video]"
query = "Taarak Mehta Ka Ooltah Chashmah - Ep 2738 - Full Episode - 24th May, 2019"

# %%
query_results = service.search().list(part = 'snippet',q = query,
                                      order = 'relevance', 
                                      type = 'video',
                                      relevanceLanguage = 'en',
                                      safeSearch = 'moderate').execute()

# %%
query_results['items']
# Out:
# [{'etag': '364zzHpOtV2d3a6i824XDEoHSVo',
#   'id': {'kind': 'youtube#video', 'videoId': 'a6RvK5U4yhc'},
#   'kind': 'youtube#searchResult',
#   'snippet': {'channelId': 'UCUWVjYXulmNzdPQFVQ4fhng',
#    'channelTitle': 'NO NAME',
#    'description': 'Taarak Mehta Ka Ooltah Chashmah 24 May 2019 full story Important Notice: All the images of this video were taken from google. taarak mehta ka ooltah ...',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2019-05-26T18:00:38Z',
#    'publishedAt': '2019-05-26T18:00:38Z',
#    'thumbnails': {'default': {'height': 90,
#      'url': 'https://i.ytimg.com/vi/a6RvK5U4yhc/default.jpg',
#      'width': 120},
#     'high': {'height': 360,
#      'url': 'https://i.ytimg.com/vi/a6RvK5U4yhc/hqdefault.jpg',
#      'width': 480},
#     'medium': {'height': 180,
#      'url': 'https://i.ytimg.com/vi/a6RvK5U4yhc/mqdefault.jpg',
#      'width': 320}},
#    'title': 'Taarak Mehta Ka Ooltah Chashmah 24 May 2019 - Episode 2738'}},
#  {'etag': 'XZ5eaY086DoqTPMGNSgd0yRIh0w',
#   'id': {'kind': 'youtube#video', 'videoId': 'vhN0T4ogXlE'},
#   'kind': 'youtube#searchResult',
#   'snippet': {'channelId': 'UCw7xjxzbMwgBSmbeYwqYRMg',
#    'channelTitle': 'Sony PAL',
#    'description': 'Subscribe to Sony Pal: http://www.youtube.com/sonypalindia Click here to Subscribe to SonyLIV: http://www.sonyliv.com/signin Episode 2072 (Part B) ...',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2019-05-27T19:45:43Z',
#    'publishedAt': '2019-05-27T19:45:43Z',
#    'thumbnails': {'default': {'height': 90,
#      'url': 'https://i.ytimg.com/vi/vhN0T4ogXlE/default.jpg',
#      'width': 120},
#     'high': {'height': 360,
#      'url': 'https://i.ytimg.com/vi/vhN0T4ogXlE/hqdefault.jpg',
#      'width': 480},
#     'medium': {'height': 180,
#      'url': 'https://i.ytimg.com/vi/vhN0T4ogXlE/mqdefault.jpg',
#      'width': 320}},
#    'title': 'Taarak Mehta Ka Ooltah Chashmah - Full Episode 2072 - 27th May, 2019'}},
#  {'etag': 'nO9sqy33Bl7HqBypQYqEEQQlC54',
#   'id': {'kind': 'youtube#video', 'videoId': 'RnNscPIrrYg'},
#   'kind': 'youtube#searchResult',
#   'snippet': {'channelId': 'UCGPYBd4-5hedRrG6_B32V0w',
#    'channelTitle': 'Qamar Samejo',
#    'description': 'Please subscribe my channel Open this link https://youtu.be/ka5jQY846U8.',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2019-05-28T19:29:29Z',
#    'publishedAt': '2019-05-28T19:29:29Z',
#    'thumbnails': {'default': {'height': 90,
#      'url': 'https://i.ytimg.com/vi/RnNscPIrrYg/default.jpg',
#      'width': 120},
#     'high': {'height': 360,
#      'url': 'https://i.ytimg.com/vi/RnNscPIrrYg/hqdefault.jpg',
#      'width': 480},
#     'medium': {'height': 180,
#      'url': 'https://i.ytimg.com/vi/RnNscPIrrYg/mqdefault.jpg',
#      'width': 320}},
#    'title': '#Tarak&#39;mehta_ka_ultah_chasmah Ep 2738 24 May, 2019'}},
#  {'etag': 'o3n8_2oYB22hDtgNNmMJnO9cybc',
#   'id': {'kind': 'youtube#video', 'videoId': 'Wrcmk-bWnQA'},
#   'kind': 'youtube#searchResult',
#   'snippet': {'channelId': 'UCpmDyavUQcJkrWj3k9eHZQQ',
#    'channelTitle': 'Parth Nagda',
#    'description': '',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2019-05-28T14:49:27Z',
#    'publishedAt': '2019-05-28T14:49:27Z',
#    'thumbnails': {'default': {'height': 90,
#      'url': 'https://i.ytimg.com/vi/Wrcmk-bWnQA/default.jpg',
#      'width': 120},
#     'high': {'height': 360,
#      'url': 'https://i.ytimg.com/vi/Wrcmk-bWnQA/hqdefault.jpg',
#      'width': 480},
#     'medium': {'height': 180,
#      'url': 'https://i.ytimg.com/vi/Wrcmk-bWnQA/mqdefault.jpg',
#      'width': 320}},
#    'title': 'Taarak Mehta Ka Ooltah Chashmah-Full episode 2739'}},
#  {'etag': 'xAhhUS1_Scj0YryeAnRCVz_sgh0',
#   'id': {'kind': 'youtube#video', 'videoId': '3YAXzcGYQsw'},
#   'kind': 'youtube#searchResult',
#   'snippet': {'channelId': 'UCw7xjxzbMwgBSmbeYwqYRMg',
#    'channelTitle': 'Sony PAL',
#    'description': 'Subscribe to Sony Pal: http://www.youtube.com/sonypalindia Click here to Subscribe to SonyLIV: http://www.sonyliv.com/signin Episode 2077: ...',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2019-05-29T16:25:18Z',
#    'publishedAt': '2019-05-29T16:25:18Z',
#    'thumbnails': {'default': {'height': 90,
#      'url': 'https://i.ytimg.com/vi/3YAXzcGYQsw/default.jpg',
#      'width': 120},
#     'high': {'height': 360,
#      'url': 'https://i.ytimg.com/vi/3YAXzcGYQsw/hqdefault.jpg',
#      'width': 480},
#     'medium': {'height': 180,
#      'url': 'https://i.ytimg.com/vi/3YAXzcGYQsw/mqdefault.jpg',
#      'width': 320}},
#    'title': 'Taarak Mehta Ka Ooltah Chashmah - Full Episode 2077 - 29th May, 2019'}}]

# %% [markdown]
# ### Extract video details i.e. videoID, channel Name, videoTitle, videoDescription

# %%
video_id = []
channel = []
video_title = []
video_desc = []
for item in query_results['items']:
    video_id.append(item['id']['videoId'])
    channel.append(item['snippet']['channelTitle'])
    video_title.append(item['snippet']['title'])
    video_desc.append(item['snippet']['description'])

# %% [markdown]
# We only wants to work with the one video so select the first element in list and save it

# %%
video_id = video_id[]
channel = channel[0]
video_title = video_title[0]
video_desc = video_desc[0]

# %%
video_id[1]
# Out:
# 'vhN0T4ogXlE'

# %% [markdown]
# ### Extract Comments
# In the next step we will extract the comments

# %%
video_id_pop = []
channel_pop = []
video_title_pop = []
video_desc_pop = []
comments_pop = []
comment_id_pop = []
reply_count_pop = []
like_count_pop = []


comments_temp = []
comment_id_temp = []
reply_count_temp = []
like_count_temp = []

# %%
nextPage_token = None

while 1:
  response = service.commentThreads().list(
                    part = 'snippet',
                    videoId = video_id,
                    maxResults = 100, 
                    order = 'relevance', 
                    textFormat = 'plainText',
                    pageToken = nextPage_token
                    ).execute()


  nextPage_token = response.get('nextPageToken')
  for item in response['items']:
      comments_temp.append(item['snippet']['topLevelComment']['snippet']['textDisplay'])
      comment_id_temp.append(item['snippet']['topLevelComment']['id'])
      reply_count_temp.append(item['snippet']['totalReplyCount'])
      like_count_temp.append(item['snippet']['topLevelComment']['snippet']['likeCount'])
      comments_pop.extend(comments_temp)
      comment_id_pop.extend(comment_id_temp)
      reply_count_pop.extend(reply_count_temp)
      like_count_pop.extend(like_count_temp)
        
      video_id_pop.extend([video_id]*len(comments_temp))
      channel_pop.extend([channel]*len(comments_temp))
      video_title_pop.extend([video_title]*len(comments_temp))
      video_desc_pop.extend([video_desc]*len(comments_temp))

  if nextPage_token is  None:
    break

# print(allVideos)
#

# %%
comments_pop
# Out:
# []

# %% [markdown]
# ### As per now comments have been extracted from youtube video and now we will save the comments into pandas dataframe and then write in csv file

# %%
output_dict = {
        'Channel': channel_pop,
        'Video Title': video_title_pop,
        'Video Description': video_desc_pop,
        'Video ID': video_id_pop,
        'Comment': comments_pop,
        'Comment ID': comment_id_pop,
        'Replies': reply_count_pop,
        'Likes': like_count_pop,
        }

output_df = pd.DataFrame(output_dict, columns = output_dict.keys())

# %%
output_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Channel            0 non-null      float64
#  1   Video Title        0 non-null      float64
#  2   Video Description  0 non-null      float64
#  3   Video ID           0 non-null      float64
#  4   Comment            0 non-null      float64
#  5   Comment ID         0 non-null      float64
#  6   Replies            0 non-null      float64
#  7   Likes              0 non-null      float64
# dtypes: float64(8)
# memory usage: 124.0 bytes

# %%
output_df.head()
# Out:
# Empty DataFrame
# Columns: [Channel, Video Title, Video Description, Video ID, Comment, Comment ID, Replies, Likes]
# Index: []

# %% [markdown]
# ### Observe the above dataframe output, many comments are repeating itself,so lets check it how many duplicate `comments` are present inthe dataframe.
# Use `pandas.dataframe.duplicated()` to get the duplicates and `pandas.dataframe.drop_duplicates()` to drop all those duplicates

# %%
duplicates = output_df[output_df.duplicated("Comment ID")]
print("Count of duplicat comments in dataframe", duplicates.shape[0])
# Out:
# Count of duplicat comments in dataframe 1615503

# %%
print("count of unique comments in dataframe ",output_df.shape[0]- duplicates.shape[0])
# Out:
# count of unique comments in dataframe  1798

# %%
unique_df = output_df.drop_duplicates(subset=['Comment'])

# %%
unique_df.shape
# Out:
# (1770, 8)

# %% [markdown]
# In the following dataframe all the comments are unique i.e. no comment appears more than once

# %%
unique_df.head()
# Out:
#     Channel                                      Video Title  ... Replies  Likes
# 0   SiaVEVO  Sia - Cheap Thrills (Lyric Video) ft. Sean Paul  ...     476  18380
# 2   SiaVEVO  Sia - Cheap Thrills (Lyric Video) ft. Sean Paul  ...       1     29
# 5   SiaVEVO  Sia - Cheap Thrills (Lyric Video) ft. Sean Paul  ...       2     25
# 9   SiaVEVO  Sia - Cheap Thrills (Lyric Video) ft. Sean Paul  ...       7    220
# 14  SiaVEVO  Sia - Cheap Thrills (Lyric Video) ft. Sean Paul  ...      52   1603
#
# [5 rows x 8 columns]

# %% [markdown]
# ## save the dataframe into csv file

# %%
unique_df.to_csv("extraced_comments.csv",index = False)

# %% [markdown]
# # Part 2
# ## Data Cleaning

# %% [markdown]
# Install `demoji` library which will be used to remove emojis from the comments

# %%
pip install demoji
# Out:
# Collecting demoji
#   Downloading https://files.pythonhosted.org/packages/da/0b/d008f26ebbfd86d21117267e627f2f7359c76e5ecbeba08d8f631f4092c4/demoji-0.2.1-py2.py3-none-any.whl
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from demoji) (47.1.1)
# Collecting colorama
#   Downloading https://files.pythonhosted.org/packages/c9/dc/45cdef1b4d119eb96316b3117e6d5708a08029992b2fee2c143c7a0a5cc5/colorama-0.4.3-py2.py3-none-any.whl
# Requirement already satisfied: requests<3.0.0 in /usr/local/lib/python3.6/dist-packages (from demoji) (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0->demoji) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0->demoji) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0->demoji) (2.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0->demoji) (2020.4.5.1)
# Installing collected packages: colorama, demoji
# Successfully installed colorama-0.4.3 demoji-0.2.1

# %%
comments = pd.read_csv('extraced_comments.csv')

# %%
comments.head()
# Out:
#    Channel                                      Video Title  ... Replies  Likes
# 0  SiaVEVO  Sia - Cheap Thrills (Lyric Video) ft. Sean Paul  ...     476  18380
# 1  SiaVEVO  Sia - Cheap Thrills (Lyric Video) ft. Sean Paul  ...       1     29
# 2  SiaVEVO  Sia - Cheap Thrills (Lyric Video) ft. Sean Paul  ...       2     25
# 3  SiaVEVO  Sia - Cheap Thrills (Lyric Video) ft. Sean Paul  ...       7    220
# 4  SiaVEVO  Sia - Cheap Thrills (Lyric Video) ft. Sean Paul  ...      52   1603
#
# [5 rows x 8 columns]

# %%
comments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1770 entries, 0 to 1769
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Channel            1770 non-null   object
#  1   Video Title        1770 non-null   object
#  2   Video Description  1770 non-null   object
#  3   Video ID           1770 non-null   object
#  4   Comment            1770 non-null   object
#  5   Comment ID         1770 non-null   object
#  6   Replies            1770 non-null   int64
#  7   Likes              1770 non-null   int64
# dtypes: int64(2), object(6)
# memory usage: 110.8+ KB

# %% [markdown]
# ### Remove Emojis
# In this step we will remove emojis from the comments using `demoji`

# %%
import demoji

# %%
comments = pd.read_csv('extraced_comments.csv')

# %%
## this step is necessary as it will download the latest emojis if updaed so as to remove all from the given texts

demoji.download_codes()
# Out:
# Downloading emoji data ...
# ... OK (Got response in 0.11 seconds)
# Writing emoji data to /root/.demoji/codes.json ...
# ... OK

# %% [markdown]
# `demoji.findall()` will gives all the emojis present in code with their tags as seen in below<br>
# `demoji.replace()` will be useful in replacing emojis from text.

# %%
comments['clean_comments'] = comments['Comment'].apply(lambda x: demoji.replace(x,""))

# %%
comments.head()
# Out:
#    Channel  ...                                     clean_comments
# 0  SiaVEVO  ...  Dear stranger who ever reads this: may your mo...
# 1  SiaVEVO  ...  Let's be honest, there is no singer in the wor...
# 2  SiaVEVO  ...  Now nobady needs money\n\n\n\n\n\n\nEverybody ...
# 3  SiaVEVO  ...  People in 2020 : "Who's here during quarantine...
# 4  SiaVEVO  ...  There are 3 types of English :\n1. American \n...
#
# [5 rows x 9 columns]

# %% [markdown]
# Use `langdetect` library to detect language of the comment

# %%
from textblob import TextBlob

# %%
from langdetect import detect

# %% [markdown]
# Now add new feature `language` inthe dataframe which signify the language of particular comment

# %%
comments['language'] = 0

# %%
count = 0
for i in range(0,len(comments)):


  temp = comments['clean_comments'].iloc[i]
  count += 1
  try:
    comments['language'].iloc[i] = detect(temp)
  except:
    comments['language'].iloc[i] = "error"
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
                                                                                                  comments.head()
# Out:
#    Channel  ... language
# 0  SiaVEVO  ...       en
# 1  SiaVEVO  ...       en
# 2  SiaVEVO  ...       en
# 3  SiaVEVO  ...       en
# 4  SiaVEVO  ...       en
#
# [5 rows x 10 columns]

# %% [markdown]
#  Check for the count of english comments

# %%
comments[comments['language']=='en']['language'].value_counts()
# Out:
# en    1267
# Name: language, dtype: int64

# %% [markdown]
# Save the english comments into csv file

# %%
english_comm = comments[comments['language'] == 'en']

# %%
english_comm.to_csv("english_comments.csv",index = False)

# %% [markdown]
# # Part 2.2

# %% [markdown]
# ### Load the dataset which contain only english comments

# %%
en_comments = pd.read_csv('english_comments.csv',encoding='utf8',error_bad_lines=False)

# %%
en_comments.head()
# Out:
#    Channel  ... language
# 0  SiaVEVO  ...       en
# 1  SiaVEVO  ...       en
# 2  SiaVEVO  ...       en
# 3  SiaVEVO  ...       en
# 4  SiaVEVO  ...       en
#
# [5 rows x 10 columns]

# %%
en_comments.shape
# Out:
# (1267, 10)

# %% [markdown]
# ### Remove brackets & special characters using Regular Expressions

# %% [markdown]
# Now first write the grammar to remove special characters from the comments

# %%
regex = r"[^0-9A-Za-z'\t]"

# %%
copy = en_comments.copy()

# %%
import re

# %%
copy['reg'] = copy['clean_comments'].apply(lambda x:re.findall(regex,x))
copy['regular_comments'] = copy['clean_comments'].apply(lambda x:re.sub(regex,"  ",x))

# %%
copy.head()
# Out:
#    Channel  ...                                   regular_comments
# 0  SiaVEVO  ...  Dear  stranger  who  ever  reads  this    may ...
# 1  SiaVEVO  ...  Let's  be  honest    there  is  no  singer  in...
# 2  SiaVEVO  ...  Now  nobady  needs  money              Everybo...
# 3  SiaVEVO  ...  People  in  2020        Who's  here  during  q...
# 4  SiaVEVO  ...  There  are  3  types  of  English      1    Am...
#
# [5 rows x 12 columns]

# %% [markdown]
# ## As now we are done with all the preprocessing part of the data.
# Now the next step will be sentiment analysis so for that we will make a new dataframe containing only `Video ID`, `Comment ID`,`regular_comments`
# <br> after that will write into a new csv file

# %%
dataset = copy[['Video ID','Comment ID','regular_comments']].copy()

# %%
dataset.head()
# Out:
#       Video ID  ...                                   regular_comments
# 0  nYh-n7EOtMA  ...  Dear  stranger  who  ever  reads  this    may ...
# 1  nYh-n7EOtMA  ...  Let's  be  honest    there  is  no  singer  in...
# 2  nYh-n7EOtMA  ...  Now  nobady  needs  money              Everybo...
# 3  nYh-n7EOtMA  ...  People  in  2020        Who's  here  during  q...
# 4  nYh-n7EOtMA  ...  There  are  3  types  of  English      1    Am...
#
# [5 rows x 3 columns]

# %%
dataset = dataset.rename(columns = {"regular_comments":"comments"})

# %%
dataset.head()
# Out:
#       Video ID  ...                                           comments
# 0  nYh-n7EOtMA  ...  Dear  stranger  who  ever  reads  this    may ...
# 1  nYh-n7EOtMA  ...  Let's  be  honest    there  is  no  singer  in...
# 2  nYh-n7EOtMA  ...  Now  nobady  needs  money              Everybo...
# 3  nYh-n7EOtMA  ...  People  in  2020        Who's  here  during  q...
# 4  nYh-n7EOtMA  ...  There  are  3  types  of  English      1    Am...
#
# [5 rows x 3 columns]

# %%
dataset.to_csv("Dataset.csv",index = False)
