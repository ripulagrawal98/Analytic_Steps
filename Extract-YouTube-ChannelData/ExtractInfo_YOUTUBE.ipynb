# %%
i = []
while(True):
  i.append('a')

# %%
 # Google Colab Setup
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os

# %%
os.chdir('/content/drive/My Drive/Analytic-Steps-blogs/YouTube/')

# %% [markdown]
# Install the relevant libraries

# %% [markdown]
# ## Install the google client library
#
# ### For Windows:
#
# `pip install google-api-python-client`
#
# ### For Ubuntu
#
# `sudo pip install google-api-python-client`
#
# ### For Anaconda
#
# `conda install google-api-python-client`

# %%
pip install google-api-python-client
# Out:
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.6/dist-packages (1.7.12)
# Requirement already satisfied: google-auth>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client) (1.7.2)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client) (3.0.1)
# Requirement already satisfied: six<2dev,>=1.6.1 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client) (1.12.0)
# Requirement already satisfied: httplib2<1dev,>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client) (0.17.3)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client) (0.0.3)
# Requirement already satisfied: cachetools<3.2,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.4.1->google-api-python-client) (3.1.1)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.4.1->google-api-python-client) (47.1.1)
# Requirement already satisfied: rsa<4.1,>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.4.1->google-api-python-client) (4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.4.1->google-api-python-client) (0.2.8)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from rsa<4.1,>=3.1.4->google-auth>=1.4.1->google-api-python-client) (0.4.8)

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (1.0.3)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas) (2018.9)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from pandas) (1.18.4)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.6.1->pandas) (1.12.0)

# %%
conda install google-api-python-client
conda install -c anaconda pandas

# %%
from googleapiclient.discovery import build
import pandas as pd

# %% [markdown]
# There are many resources available with the API which can be retreieved from the youtube.They include:
#
# *   **Channel** It contains information about the channel of youtube. Information like total number of videos including their total likes/dislikes, comments and subscriber etc.
# *   Playlists

# %%
youTubeApiKey="AIzaSyCoBcCAxIGkTf5WKxAiXJu48APdyQjqU0I"
youtube=build('youtube','v3',developerKey=youTubeApiKey)

# %% [markdown]
# In the next step we will try to find out the channel id and the related information using the <b>display name</b> of channel at youtube.<br>
# likewise I am using <b>NPTEL</b><br>
#
# Here we are going to find the details of channel resources.There are different properties, which can be used i.e. information corresponding to that property like
# * **snippet** which provide the basic details about the channel
# * **Statistics** provides the statistics of the channel

# %% [markdown]
# ## Resource - **Channel**
# ### Property - **Snippets**

# %%
snippets = youtube.search().list(part="snippet", type="channel", q="nptelhrd").execute()

# %%
snippets
# Out:
# {'etag': 'Z3QqWxqnsnFVG-2LIXyMY20Dyv4',
#  'items': [{'etag': 'OVuQK49xKdDqN0sN36X69QyFwtQ',
#    'id': {'channelId': 'UC640y4UvDAlya_WOj5U4pfA', 'kind': 'youtube#channel'},
#    'kind': 'youtube#searchResult',
#    'snippet': {'channelId': 'UC640y4UvDAlya_WOj5U4pfA',
#     'channelTitle': 'nptelhrd',
#     'description': 'Your favorite courses available for certification! study, write an exam and get a certificate from the IITs! Check http://nptel.ac.in/noc This channel provides ...',
#     'liveBroadcastContent': 'upcoming',
#     'publishTime': '2007-11-28T04:54:13Z',
#     'publishedAt': '2007-11-28T04:54:13Z',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/-VO_A5Tys4WY/AAAAAAAAAAI/AAAAAAAAAAA/mBvvbUvh0A8/s88-c-k-no-mo-rj-c0xffffff/photo.jpg'},
#      'high': {'url': 'https://yt3.ggpht.com/-VO_A5Tys4WY/AAAAAAAAAAI/AAAAAAAAAAA/mBvvbUvh0A8/s800-c-k-no-mo-rj-c0xffffff/photo.jpg'},
#      'medium': {'url': 'https://yt3.ggpht.com/-VO_A5Tys4WY/AAAAAAAAAAI/AAAAAAAAAAA/mBvvbUvh0A8/s240-c-k-no-mo-rj-c0xffffff/photo.jpg'}},
#     'title': 'nptelhrd'}},
#   {'etag': 'B5pNo_KG9nG0N_P8G26osu9sqlk',
#    'id': {'channelId': 'UCTJn6buigC961hns17ELXAQ', 'kind': 'youtube#channel'},
#    'kind': 'youtube#searchResult',
#    'snippet': {'channelId': 'UCTJn6buigC961hns17ELXAQ',
#     'channelTitle': 'Electrical Engineering',
#     'description': 'This channel contains technical lectures on "Electrical Engineering" from seven Indian Institutes of Technology (IITs) and Indian Institute of Science (IISc), ...',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2013-11-27T11:22:52Z',
#     'publishedAt': '2013-11-27T11:22:52Z',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/
s240-c-k-no-mo-rj-c0xffffff/photo.jpg'}},
#     'title': 'Humanities and Social Sciences'}}],
#  'kind': 'youtube#searchListResponse',
#  'nextPageToken': 'CAUQAA',
#  'pageInfo': {'resultsPerPage': 5, 'totalResults': 13},
#  'regionCode': 'US'}

# %%
print(snippets)
# Out:
# {'kind': 'youtube#searchListResponse', 'etag': 'Z3QqWxqnsnFVG-2LIXyMY20Dyv4', 'nextPageToken': 'CAUQAA', 'regionCode': 'US', 'pageInfo': {'totalResults': 13, 'resultsPerPage': 5}, 'items': [{'kind': 'youtube#searchResult', 'etag': 'OVuQK49xKdDqN0sN36X69QyFwtQ', 'id': {'kind': 'youtube#channel', 'channelId': 'UC640y4UvDAlya_WOj5U4pfA'}, 'snippet': {'publishedAt': '2007-11-28T04:54:13Z', 'channelId': 'UC640y4UvDAlya_WOj5U4pfA', 'title': 'nptelhrd', 'description': 'Your favorite courses available for certification! study, write an exam and get a certificate from the IITs! Check http://nptel.ac.in/noc This channel provides ...', 'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/-VO_A5Tys4WY/AAAAAAAAAAI/AAAAAAAAAAA/mBvvbUvh0A8/s88-c-k-no-mo-rj-c0xffffff/photo.jpg'}, 'medium': {'url': 'https://yt3.ggpht.com/-VO_A5Tys4WY/AAAAAAAAAAI/AAAAAAAAAAA/mBvvbUvh0A8/s240-c-k-no-mo-rj-c0xffffff/photo.jpg'}, 'high': {'url': 'https://yt3.ggpht.com/-VO_A5Tys4WY/AAAAAAAAAAI/AAAAAAAAAAA/mBvvbUvh0A8/s800-c-k-no-mo-rj-c0xffffff/photo.jpg'}}, 'channelTitle': 'nptelhrd', 'liveBroadcastContent': 'upcoming', 'publishTime': '2007-11-28T04:54:13Z'}}, {'kind': 'youtube#searchResult', 'etag': 'B5pNo_KG9nG0N_P8G26osu9sqlk', 'id': {'kind': 'youtube#channel', 'channelId': 'UCTJn6buigC961hns17ELXAQ'}, 'snippet': {'publishedAt': '2013-11-27T11:22:52Z', 'channelId': 'UCTJn6buigC961hns17ELXAQ', 'title': 'Electrical Engineering', 'description': 'This channel contains technical lectures on "Electrical Engineering" from seven Indian Institutes of Technology (IITs) and Indian Institute of Science (IISc), ...', 'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/-QfsJhnpgezc/AAAAAAAAAAI/AAAAAAAAAAA/lMAzqmuE1no/s88-c-k-no-mo-rj-c0xffffff/photo.jpg'}, 'medium': {'url': 'https://yt3.ggpht.com/-QfsJhnpgezc/AAAAAAAAAAI/AAAAAAAAAAA/lMAzqmuE1no/s240-c-k-no-mo-rj-c0xffffff/photo.jpg'}, 'high': {'url': 'https://yt3.ggpht.com/-QfsJhnpgezc/AAAAAAAAAAI/AAAAAAAAAAA/lMAzqmuE1no/s800-c-k-no-mo-rj-c0xffffff/photo.jpg'}}, 'channelTitle': 'Electrical Engineering', 'liveBroadcastContent': 'none', 'publishTime': '2013-11-27T11:22:52Z'}}, {'kind': 'youtube#searchResult', 'etag': 'hSoJfJUz0SdO-q-dTFJkDbSia6Y', 'id': {'kind': 'youtube#channel', 'channelId': 'UC9vycSfjzLCR_w1C59VQo5A'}, 'snippet': {'publishedAt': '2013-11-27T11:33:24Z', 'channelId': 'UC9vycSfjzLCR_w1C59VQo5A', 'title': 'Physics', 'description': 'This channel contains technical lectures on "Physics" from seven Indian Institutes of Technology (IITs) and Indian Institute of Science (IISc), Bangalore. Please ...', 'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/-BMtJstuPzPc/AAAAAAAAAAI/AAAAAAAAAAA/bZ4rYcsSLAQ/s88-c-k-no-mo-rj-c0xffffff/photo.jpg'}, 'medium': {'url': 'https://yt3.ggpht.com/-BMtJstuPzPc/AAAAAAAAAAI/AAAAAAAAAAA/bZ4rYcsSLAQ/s240-c-k-no-mo-rj-c0xffffff/photo.jpg'}, 'high': {'url': 'https://yt3.ggpht.com/-BMtJstuPzPc/AAAAAAAAAAI/AAAAAAAAAAA/bZ4rYcsSLAQ/s800-c-k-no-mo-rj-c0xffffff/photo.jpg'}}, 'channelTitle': 'Physics', 'liveBroadcastContent': 'none', 'publishTime': '2013-11-27T11:33:24Z'}}, {'kind': 'youtube#searchResult', 'etag': 'TJWKwHlQ1trW2xGKPcBuh1lYS4Y', 'id': {'kind': 'youtube#channel', 'channelId': 'UCW6912n7NwlBO7rPTIxHm0w'}, 'snippet': {'publishedAt': '2013-11-27T11:28:28Z', 'channelId': 'UCW6912n7NwlBO7rPTIxHm0w', 'title': 'Mathematics', 'description': 'This channel contains technical lectures on "Mathematics" from seven Indian Institutes of Technology (IITs) and Indian Institute of Science (IISc), Bangalore.', 'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/-7gb9Oec3H88/AAAAAAAAAAI/AAAAAAAAAAA/g5nAPmE1ng0/s88-c-k-no-mo-rj-c0xffffff/photo.jpg'}, 'medium': {'url': 'https://yt3.ggpht.com/-7gb9Oec3H88/AAAAAAAAAAI/AAAAAAAAAAA/g5nAPmE1ng0/s240-c-k-no-mo-rj-c0xffffff/photo.jpg'}, 'high': {'url': 'https://yt3.ggpht.com/-7gb9Oec3H88/AAAAAAAAAAI/AAAAAAAAAAA/g5nAPmE1ng0/s800-c-k-no-mo-rj-c0xffffff/photo.jpg'}}, 'channelTitle': 'Mathematics', 'liveBroadcastContent': 'none', 'publishTime':  ...

# %%
for item in snippets:
  print(item)
# Out:
# kind
# etag
# nextPageToken
# regionCode
# pageInfo
# items

# %%
for key,value in snippets.items():
  print(key,"*************",value)
# Out:
# kind ************* youtube#searchListResponse
# etag ************* Z3QqWxqnsnFVG-2LIXyMY20Dyv4
# nextPageToken ************* CAUQAA
# regionCode ************* US
# pageInfo ************* {'totalResults': 13, 'resultsPerPage': 5}
# items ************* [{'kind': 'youtube#searchResult', 'etag': 'OVuQK49xKdDqN0sN36X69QyFwtQ', 'id': {'kind': 'youtube#channel', 'channelId': 'UC640y4UvDAlya_WOj5U4pfA'}, 'snippet': {'publishedAt': '2007-11-28T04:54:13Z', 'channelId': 'UC640y4UvDAlya_WOj5U4pfA', 'title': 'nptelhrd', 'description': 'Your favorite courses available for certification! study, write an exam and get a certificate from the IITs! Check http://nptel.ac.in/noc This channel provides ...', 'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/-VO_A5Tys4WY/AAAAAAAAAAI/AAAAAAAAAAA/mBvvbUvh0A8/s88-c-k-no-mo-rj-c0xffffff/photo.jpg'}, 'medium': {'url': 'https://yt3.ggpht.com/-VO_A5Tys4WY/AAAAAAAAAAI/AAAAAAAAAAA/mBvvbUvh0A8/s240-c-k-no-mo-rj-c0xffffff/photo.jpg'}, 'high': {'url': 'https://yt3.ggpht.com/-VO_A5Tys4WY/AAAAAAAAAAI/AAAAAAAAAAA/mBvvbUvh0A8/s800-c-k-no-mo-rj-c0xffffff/photo.jpg'}}, 'channelTitle': 'nptelhrd', 'liveBroadcastContent': 'upcoming', 'publishTime': '2007-11-28T04:54:13Z'}}, {'kind': 'youtube#searchResult', 'etag': 'B5pNo_KG9nG0N_P8G26osu9sqlk', 'id': {'kind': 'youtube#channel', 'channelId': 'UCTJn6buigC961hns17ELXAQ'}, 'snippet': {'publishedAt': '2013-11-27T11:22:52Z', 'channelId': 'UCTJn6buigC961hns17ELXAQ', 'title': 'Electrical Engineering', 'description': 'This channel contains technical lectures on "Electrical Engineering" from seven Indian Institutes of Technology (IITs) and Indian Institute of
from seven Indian Institutes of Technology (IITs) and Indian Institute of Science (IISc), Bangalore.', 'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/-7gb9Oec3H88/AAAAAAAAAAI/AAAAAAAAAAA/g5nAPmE1ng0/s88-c-k-no-mo-rj-c0xffffff/photo.jpg'}, 'medium': {'url': 'https://yt3.ggpht.com/-7gb9Oec3H88/AAAAAAAAAAI/AAAAAAAAAAA/g5nAPmE1ng0/s240-c-k-no-mo-rj-c0xffffff/photo.jpg'}, 'high': {'url': 'https://yt3.ggpht.com/-7gb9Oec3H88/AAAAAAAAAAI/AAAAAAAAAAA/g5nAPmE1ng0/s800-c-k-no-mo-rj-c0xffffff/photo.jpg'}}, 'channelTitle': 'Mathematics', 'liveBroadcastContent': 'none', 'publishTime': '2013-11-27T11:28:28Z'}}
# {'kind': 'youtube#searchResult', 'etag': 'WyKaDpZ-VXg2M4vA-vOzTWQ3ZvE', 'id': {'kind': 'youtube#channel', 'channelId': 'UCnLoshotJ_FRpzFmOChRPaQ'}, 'snippet': {'publishedAt': '2013-11-27T11:27:07Z', 'channelId': 'UCnLoshotJ_FRpzFmOChRPaQ', 'title': 'Humanities and Social Sciences', 'description': 'This channel contains technical lectures on "Humanities and Social Science" from seven Indian Institutes of Technology (IITs) and Indian Institute of Science ...', 'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/-2sY7Qb3CNek/AAAAAAAAAAI/AAAAAAAAAAA/m_UOi3MWjx8/s88-c-k-no-mo-rj-c0xffffff/photo.jpg'}, 'medium': {'url': 'https://yt3.ggpht.com/-2sY7Qb3CNek/AAAAAAAAAAI/AAAAAAAAAAA/m_UOi3MWjx8/s240-c-k-no-mo-rj-c0xffffff/photo.jpg'}, 'high': {'url': 'https://yt3.ggpht.com/-2sY7Qb3CNek/AAAAAAAAAAI/AAAAAAAAAAA/m_UOi3MWjx8/s800-c-k-no-mo-rj-c0xffffff/photo.jpg'}}, 'channelTitle': 'Humanities and Social Sciences', 'liveBroadcastContent': 'none', 'publishTime': '2013-11-27T11:27:07Z'}}

# %% [markdown]
# From the above blocks of code we can see that by using property **snippets**  we got all the information related with the channel,actually information of all the related channels including **channelId, title, description,thumbnails and publishTime**

# %%
## Now extract the channelId,of the first channel in list, as follows: 

channelId = snippets['items'][0]['snippet']['channelId']

print("Channel ID of the first channel is "+ channelId)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-260ae6168a7c> in <module>()
#       1 ## Now extract the channelId,of the first channel in list, as follows:
#       2
# ----> 3 channelId = snippets['items'][0]['snippet']['channelId']
#       4
#       5 print("Channel ID of the first channel is "+ channelId)
#
# NameError: name 'snippets' is not defined

# %%
print("Channel "+snippets['items'][0]['snippet']['title'] +" is published at "+snippets['items'][0]['snippet']['publishedAt'])
print("Here is the description avaiable at the channel page on youtube \n")
print(snippets['items'][0]['snippet']['description'])
# Out:
# Channel nptelhrd is published at 2007-11-28T04:54:13Z
# Here is the description avaiable at the channel page on youtube
#
# Your favorite courses available for certification! study, write an exam and get a certificate from the IITs! Check http://nptel.ac.in/noc This channel provides ...

# %% [markdown]
# ### Property - **Statistics**

# %%
stats = youtube.channels().list(part="statistics", id = channelId).execute()

# %%
stats['items']
# Out:
# [{'etag': 'RpK_p-ZmFOqgyOCGX3pVBWTU064',
#   'id': 'UC640y4UvDAlya_WOj5U4pfA',
#   'kind': 'youtube#channel',
#   'statistics': {'commentCount': '0',
#    'hiddenSubscriberCount': False,
#    'subscriberCount': '1700000',
#    'videoCount': '20267',
#    'viewCount': '369594590'}}]

# %%
stats
# Out:
# {'etag': 'p6va5bQot7h9a4n3-zeYDDuVzs4',
#  'items': [{'etag': 'RpK_p-ZmFOqgyOCGX3pVBWTU064',
#    'id': 'UC640y4UvDAlya_WOj5U4pfA',
#    'kind': 'youtube#channel',
#    'statistics': {'commentCount': '0',
#     'hiddenSubscriberCount': False,
#     'subscriberCount': '1700000',
#     'videoCount': '20267',
#     'viewCount': '369594590'}}],
#  'kind': 'youtube#channelListResponse',
#  'pageInfo': {'resultsPerPage': 1, 'totalResults': 1}}

# %%
for item in stats:
  print(item)
# Out:
# kind
# etag
# pageInfo
# items

# %% [markdown]
# In the following cell we will see the statistics of particular channel which we acquired using API, which includes **total subscribers, videoCounts, viewCounts**

# %%
print("Total Number of Subscribers of "+snippets['items'][0]['snippet']['title'] + " is "+stats['items'][0]['statistics']['subscriberCount'])
print("Total Number of Videos Uploaded at "+snippets['items'][0]['snippet']['title'] + " is "+stats['items'][0]['statistics']['videoCount'])
print("Total Number of view on all videos of "+snippets['items'][0]['snippet']['title'] + " is "+stats['items'][0]['statistics']['viewCount'])
# Out:
# Total Number of Subscribers of nptelhrd is 1700000
# Total Number of Videos Uploaded at nptelhrd is 20267
# Total Number of view on all videos of nptelhrd is 369594590

# %% [markdown]
# ### Property - **ContentDetails**
#
# In this we will get the details of all the videos related to that channel

# %%
content = youtube.channels().list(id = channelId, part = 'contentDetails').execute()
print(content)
# Out:
# {'kind': 'youtube#channelListResponse', 'etag': 'BBq-B49JTLJYceD2sBcIWwcyu1U', 'pageInfo': {'totalResults': 1, 'resultsPerPage': 1}, 'items': [{'kind': 'youtube#channel', 'etag': 'DGewDQt1SQgoHcBkGds7SSA1Kbs', 'id': 'UC640y4UvDAlya_WOj5U4pfA', 'contentDetails': {'relatedPlaylists': {'likes': '', 'favorites': '', 'uploads': 'UU640y4UvDAlya_WOj5U4pfA', 'watchHistory': 'HL', 'watchLater': 'WL'}}}]}

# %%
content['items']
# Out:
# [{'contentDetails': {'relatedPlaylists': {'favorites': '',
#     'likes': '',
#     'uploads': 'UU640y4UvDAlya_WOj5U4pfA',
#     'watchHistory': 'HL',
#     'watchLater': 'WL'}},
#   'etag': 'DGewDQt1SQgoHcBkGds7SSA1Kbs',
#   'id': 'UC640y4UvDAlya_WOj5U4pfA',
#   'kind': 'youtube#channel'}]

# %%
UploadId = content['items'][0]['contentDetails']['relatedPlaylists']['uploads']
print("The Id of the upload playlist of this channel "+UploadId+" .In this playlist all the uploaded videos by this channels.")
# Out:
# The Id of the upload playlist of this channel UU640y4UvDAlya_WOj5U4pfA .In this playlist all the uploaded videos by this channels.

# %%
content
# Out:
# {'etag': 'BBq-B49JTLJYceD2sBcIWwcyu1U',
#  'items': [{'contentDetails': {'relatedPlaylists': {'favorites': '',
#      'likes': '',
#      'uploads': 'UU640y4UvDAlya_WOj5U4pfA',
#      'watchHistory': 'HL',
#      'watchLater': 'WL'}},
#    'etag': 'DGewDQt1SQgoHcBkGds7SSA1Kbs',
#    'id': 'UC640y4UvDAlya_WOj5U4pfA',
#    'kind': 'youtube#channel'}],
#  'kind': 'youtube#channelListResponse',
#  'pageInfo': {'resultsPerPage': 1, 'totalResults': 1}}

# %%
for item in content:
  print(item)
# Out:
# kind
# etag
# pageInfo
# items

# %% [markdown]
# In the next cell you will see the playlists of the channel which includes the **liked and uploads** on the channel.<br>
# Liked videos include the videos liked by channel<br>Uploads will include the videos uploaded by the channel

# %%
content['items'][0]['contentDetails']['relatedPlaylists']
# Out:
# {'favorites': '',
#  'likes': '',
#  'uploads': 'UU640y4UvDAlya_WOj5U4pfA',
#  'watchHistory': 'HL',
#  'watchLater': 'WL'}

# %% [markdown]
# ### Property - **Status**
#
# It includes the information about the privacy status of the channel

# %%
status = youtube.channels().list(id = channelId, part = 'status').execute()
print(status)
# Out:
# {'kind': 'youtube#channelListResponse', 'etag': 'hcYH6teDeSUBkPE8Nh_Qu3HX0jo', 'pageInfo': {'totalResults': 1, 'resultsPerPage': 1}, 'items': [{'kind': 'youtube#channel', 'etag': 'I-oY5UpVp638jpuJ7vBQFjWwvQo', 'id': 'UC640y4UvDAlya_WOj5U4pfA', 'status': {'privacyStatus': 'public', 'isLinked': True, 'longUploadsStatus': 'longUploadsUnspecified', 'madeForKids': False}}]}

# %%
status
# Out:
# {'etag': 'hcYH6teDeSUBkPE8Nh_Qu3HX0jo',
#  'items': [{'etag': 'I-oY5UpVp638jpuJ7vBQFjWwvQo',
#    'id': 'UC640y4UvDAlya_WOj5U4pfA',
#    'kind': 'youtube#channel',
#    'status': {'isLinked': True,
#     'longUploadsStatus': 'longUploadsUnspecified',
#     'madeForKids': False,
#     'privacyStatus': 'public'}}],
#  'kind': 'youtube#channelListResponse',
#  'pageInfo': {'resultsPerPage': 1, 'totalResults': 1}}

# %%
for item in status:
  print(item)
# Out:
# kind
# etag
# pageInfo
# items

# %%
status['items'][0]['status']
# Out:
# {'isLinked': True,
#  'longUploadsStatus': 'longUploadsUnspecified',
#  'madeForKids': False,
#  'privacyStatus': 'public'}

# %%
print("Privacy Status of this channel is "+status['items'][0]['status']['privacyStatus'])
# Out:
# Privacy Status of this channel is public

# %%
if(status['items'][0]['status']['madeForKids'] == True):
  print("This channel include videos for Kids")
else:
  print("This channel is not for kids")
# Out:
# This channel is not for kids

# %% [markdown]
# ## Resources: **ChannelSection**

# %%
channelSections = youtube.channelSections().list(channelId = channelId, part = 'snippet').execute()

# %%
channelSections
# Out:
# {'etag': 'X8tvypAOMhcIloh5Iq75cF8soz4',
#  'items': [{'etag': 'AwLlCChZ0WPh__b_leMhhZ0n_mA',
#    'id': 'UCr2dD3s19bdcw4qjuUTQKiQ.jNQXAC9IVRw',
#    'kind': 'youtube#channelSection',
#    'snippet': {'channelId': 'UCr2dD3s19bdcw4qjuUTQKiQ',
#     'position': 0,
#     'style': 'horizontalRow',
#     'type': 'recentUploads'}},
#   {'etag': 'd5_Tslw-Mm3slTiyA5Nno8dXX00',
#    'id': 'UCr2dD3s19bdcw4qjuUTQKiQ.LeAltgu_pbM',
#    'kind': 'youtube#channelSection',
#    'snippet': {'channelId': 'UCr2dD3s19bdcw4qjuUTQKiQ',
#     'position': 1,
#     'style': 'horizontalRow',
#     'type': 'allPlaylists'}}],
#  'kind': 'youtube#channelSectionListResponse'}

# %%
channelSections['items'][0]
# Out:
# {'etag': 'AwLlCChZ0WPh__b_leMhhZ0n_mA',
#  'id': 'UCr2dD3s19bdcw4qjuUTQKiQ.jNQXAC9IVRw',
#  'kind': 'youtube#channelSection',
#  'snippet': {'channelId': 'UCr2dD3s19bdcw4qjuUTQKiQ',
#   'position': 0,
#   'style': 'horizontalRow',
#   'type': 'recentUploads'}}

# %% [markdown]
# ## Resources - **PlaylistItems**

# %% [markdown]
# **nextPageToken** it will be used as the value of pageToken parameter to retrieve the previous page details. It will be useful as when we will be retireve the playlistItems in the above cell then there is maxium limit of 50 Items i.e. only retrieve the 50 items per search.<br>
# So to retrieve the information of all videos, we will be using while loop and nextPageToken as inthe following cell:

# %%
# declare an empty list where we will store the information retrievd of all the uploaded videos on the channel

allVideos = []

# %%
nextPage_token = None

# %%
res = youtube.playlistItems().list(playlistId = UploadId,maxResults = 50,part = 'snippet',pageToken = nextPage_token).execute()

# %%
while 1:
  res = youtube.playlistItems().list(playlistId = UploadId,maxResults = 50,part = 'snippet',pageToken = nextPage_token).execute()

  allVideos += res['items']

  nextPage_token = res.get('nextPageToken')

  if nextPage_token is  None:
    break

print(allVideos)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
len(allVideos)
# Out:
# 20267

# %% [markdown]
# Now all the information related to all the uploaded videos on this youtube channel got saved inthis list

# %%
print("total number of videos uploaded on this channel is ", len(allVideos))
# Out:
# total number of videos uploaded on this channel is  20267

# %%
allVideos[0]['snippet']
# Out:
# {'channelId': 'UC640y4UvDAlya_WOj5U4pfA',
#  'channelTitle': 'nptelhrd',
#  'description': 'Learning the idea of data flow in a more pragmatic way not only helped Ashish from Avanthi Institute of Engineering and Technology understand the concept with more clarity, but also helped him during his job interviews. He has got a job offer from ValueMomentum.',
#  'playlistId': 'UU640y4UvDAlya_WOj5U4pfA',
#  'position': 0,
#  'publishedAt': '2020-05-26T12:04:05Z',
#  'resourceId': {'kind': 'youtube#video', 'videoId': '-IxxbRxdx_Q'},
#  'thumbnails': {'default': {'height': 90,
#    'url': 'https://i.ytimg.com/vi/-IxxbRxdx_Q/default.jpg',
#    'width': 120},
#   'high': {'height': 360,
#    'url': 'https://i.ytimg.com/vi/-IxxbRxdx_Q/hqdefault.jpg',
#    'width': 480},
#   'maxres': {'height': 720,
#    'url': 'https://i.ytimg.com/vi/-IxxbRxdx_Q/maxresdefault.jpg',
#    'width': 1280},
#   'medium': {'height': 180,
#    'url': 'https://i.ytimg.com/vi/-IxxbRxdx_Q/mqdefault.jpg',
#    'width': 320},
#   'standard': {'height': 480,
#    'url': 'https://i.ytimg.com/vi/-IxxbRxdx_Q/sddefault.jpg',
#    'width': 640}},
#  'title': "NPTEL plays a pivotal role in Subhadip's preparation for entrance exams"}

# %%
print("Display the information related to the latest uploaded video on the channel\n")
print("Title of latest video uploaded: "+ allVideos[0]['snippet']['title'])
print("The latest video uploaded on date: "+allVideos[0]['snippet']['publishedAt'])
# Out:
# Display the information related to the latest uploaded video on the channel
#
# Title of latest video uploaded: NPTEL plays a pivotal role in Subhadip's preparation for entrance exams
# The latest video uploaded on date: 2020-05-26T12:04:05Z

# %% [markdown]
# ### Retrieve the videoIDs of all the videos

# %%
video_ids = list(map(lambda x:x['snippet']['resourceId']['videoId'], allVideos))
print(len(video_ids))
# Out:
# 20267

# %%
stats = []
for i in range(0, len(video_ids), 40):
  res = (youtube).videos().list(id=','.join(video_ids[i:i+40]),part='statistics').execute()
  stats += res['items']
print(stats)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
stats[0]
# Out:
# {'etag': '2afakuLushA5DUaj4QTDr8dPfIU',
#  'id': '-IxxbRxdx_Q',
#  'kind': 'youtube#video',
#  'statistics': {'commentCount': '0',
#   'dislikeCount': '3',
#   'favoriteCount': '0',
#   'likeCount': '12',
#   'viewCount': '618'}}

# %% [markdown]
# Now we will retrieved the complete details of all videos individually uploaded on the channel- youtube and will save in dataframe as csv file.<br>
# including the:
# * videoTitle
# * videoID
# * likedCount
# * dislikedCount
# * viewCount
# * commentCount

# %%
title=[ ]
liked=[ ]
disliked=[ ]
views=[ ]
url=[ ]
comment=[ ]
videoid = []
publishedDate = []
video_description = []

# %%
for i in range(0,20060):
  # print(i)
  i += 1
  title.append((allVideos[i])['snippet']['title'])
  publishedDate.append((allVideos[i])['snippet']['publishedAt'])
  video_description.append((allVideos[i])['snippet']['description'])
  liked.append(int((stats[i])['statistics']['likeCount']))
  disliked.append(int((stats[i])['statistics']['dislikeCount']))
  views.append(int((stats[i])['statistics']['viewCount']))
  comment.append(int((stats[i])['statistics']['commentCount']))
  videoid.append(allVideos[i]['snippet']['resourceId']['videoId'])

# %%
import pandas as pd
data={'title':title,'videoIDS':videoid,'video_description':video_description,'publishedDate':publishedDate,'likes':liked,'dislikes':disliked,'views':views,'comment':comment}
df=pd.DataFrame(data)
df.head()
# Out:
#                                                title  ... comment
# 0  Saavi credits NPTEL courses for helping her in...  ...       2
# 1  One course can change one's life - it did chan...  ...       1
# 2  From coding courses to coding rounds - how Pay...  ...       3
# 3  NPTEL courses taught Mohit the skill of attent...  ...       0
# 4  Harischandra's interest to explore the finer n...  ...       0
#
# [5 rows x 8 columns]

# %%
df.to_csv('ExtractedData.csv',index = False)

# %%
df['title'].iloc[0]
# Out:
# 'Saavi credits NPTEL courses for helping her in exploring topics of interest'
